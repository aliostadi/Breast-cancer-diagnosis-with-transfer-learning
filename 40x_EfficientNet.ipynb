# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Tue Nov 22 19:00:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import psutil
def get_size(bytes, suffix="B"):
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f"{bytes:.2f}{unit}{suffix}"
        bytes /= factor
print("="*40, "Memory Information", "="*40)
svmem = psutil.virtual_memory()
print(f"Total: {get_size(svmem.total)}") ; print(f"Available: {get_size(svmem.available)}")
print(f"Used: {get_size(svmem.used)}") ; print(f"Percentage: {svmem.percent}%")
# Out:
# ======================================== Memory Information ========================================
# Total: 12.68GB
# Available: 11.49GB
# Used: 1017.46MB
# Percentage: 9.4%

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import EfficientNetB4,Xception,InceptionResNetV2,ResNet50
from tensorflow.keras.applications import DenseNet121,DenseNet201,InceptionV3
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import os
import cv2
import time
from keras.applications.vgg16 import VGG16,preprocess_input
from keras.models import Sequential
from keras.layers import Dense,Flatten,Dropout,Concatenate,GlobalAveragePooling2D,Lambda,ZeroPadding2D
from keras.layers import SeparableConv2D,BatchNormalization,MaxPooling2D,Conv2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam,SGD

# %%
path= list(paths.list_images("/content/drive/MyDrive/breast-cancer-classification/tf_files/breast_40"))
len(path)
data=[]
labels=[]
p =0
# loop over the image paths
for imagePath in path:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]

	# load the input image (224x224) and preprocess it
	image = cv2.imread(imagePath)
	# image = cv2.resize(image,(224,224) , cv2.INTER_NEAREST )
	p = p+ 1
	print(p)
	# update the data and labels lists, respectively
	data.append(image[224:448 , 224:448])
	labels.append(label)

# %%
class_ = np.unique(labels,return_counts=True)
print(class_[1][0] , class_[1][1])

b = float(len(data)) / (2*class_[1][0])  ######## The number of benign training classes
m = float(len(data)) / (2*class_[1][1])  ######## Number of malignant test classes
class_weight = {0:b , 1:m}
print('class weight:', class_weight)
# Out:
# 625 1370
# class weight: {0: 1.596, 1: 0.7281021897810219}

# %%
data = np.array(data)
labels = np.array(labels)

# %%
data_train, data_test, labels_train, labels_test = train_test_split( data, labels, test_size=0.20, random_state=42)

# %%
print(data_train.shape , data_test.shape)
print(labels_train.shape , labels_test.shape)
# Out:
# (1596, 224, 224, 3) (399, 224, 224, 3)
# (1596,) (399,)

# %%
lb = LabelBinarizer()
labels_train = lb.fit_transform(labels_train)
labels_train = to_categorical(labels_train,num_classes=2)


labels_test = lb.fit_transform(labels_test)
labels_test = to_categorical(labels_test,num_classes=2)

# %%
baseModel = EfficientNetB4(include_top=False, input_tensor=Input(shape=(224, 224, 3)), weights = 'imagenet')
headModel = baseModel.output
headModel =GlobalAveragePooling2D()(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel=Dropout(0.3)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

model = Model(inputs=baseModel.input, outputs=headModel)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 [==============================] - 4s 0us/step

# %%
import random

def Data_generator(X,y, batch_size=8, augment=False):
    
    while True:
               
          for start in range(0, X.shape[0], batch_size):
              x_batch = []
              y_batch = []

              end = min(start + batch_size, X.shape[0])
              ids_batch = X[start:end]
              ids_batch1 = y[start:end]

              for idd in range(start,end):
              
                   a=random.randint(0,2)
                   if a==0:
                      image =X[idd] /255
                      image =np.fliplr(image) 
                      label =y[idd]
   
                   if a==1:
                      image =X[idd] /255
                      image =np.fliplr(image) 
                      label =y[idd]
                   elif a==2:
                      image =X[idd] /255
                      label =y[idd]

                  
                   x_batch.append(image)
                   y_batch.append(label)
                 
              x_batch= np.array(x_batch)
              y_batch= np.array(y_batch)
                          
                      
                   
              yield x_batch, y_batch

# %%
m,b=next(iter(Data_generator(data_train,labels_train)))
print(m.shape)
print(b.shape)
plt.imshow(m[0])
# Out:
# (8, 224, 224, 3)
# (8, 2)

# %%
import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
optim = keras.optimizers.Adam(learning_rate =0.00008)
model.compile(optim, loss="binary_crossentropy", metrics=['accuracy'])

def step_decay(epoch):
     
     initAlpha = 0.00008
     factor = .6
     dropEvery = 25
     alpha = initAlpha * (factor ** np.floor((1 + epoch) / dropEvery))
     return float(alpha)

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
batch_size =8
TrainSteps = len(data_train) // batch_size     
ValSteps   = len(data_test) // 1
model_checkpoint = ModelCheckpoint('/content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5', save_best_only=True, verbose=2, monitor='val_accuracy',mode='max')
csv_logger = CSVLogger('/content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.csv', append=True)


H = model.fit_generator(Data_generator(data_train,labels_train), epochs = 50 , steps_per_epoch=TrainSteps, validation_data =Data_generator(data_test,labels_test) ,
                validation_steps =ValSteps,
callbacks=[model_checkpoint, csv_logger , LearningRateScheduler(step_decay)],shuffle=True , class_weight=class_weight )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/50
# 199/199 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.7274
# Epoch 1: val_accuracy improved from -inf to 0.66436, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 95s 342ms/step - loss: 0.5197 - accuracy: 0.7274 - val_loss: 0.6439 - val_accuracy: 0.6644 - lr: 8.0000e-05
# Epoch 2/50
# 199/199 [==============================] - ETA: 0s - loss: 0.2877 - accuracy: 0.8917
# Epoch 2: val_accuracy did not improve from 0.66436
# 199/199 [==============================] - 63s 309ms/step - loss: 0.2877 - accuracy: 0.8917 - val_loss: 0.7099 - val_accuracy: 0.5284 - lr: 8.0000e-05
# Epoch 3/50
# 199/199 [==============================] - ETA: 0s - loss: 0.1738 - accuracy: 0.9251
# Epoch 3: val_accuracy improved from 0.66436 to 0.70769, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 66s 334ms/step - loss: 0.1738 - accuracy: 0.9251 - val_loss: 0.6930 - val_accuracy: 0.7077 - lr: 8.0000e-05
# Epoch 4/50
# 199/199 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9559
# Epoch 4: val_accuracy did not improve from 0.70769
# 199/199 [==============================] - 62s 312ms/step - loss: 0.1090 - accuracy: 0.9559 - val_loss: 0.8530 - val_accuracy: 0.5786 - lr: 8.0000e-05
# Epoch 5/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9729
# Epoch 5: val_accuracy improved from 0.70769 to 0.71931, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 67s 335ms/step - loss: 0.0794 - accuracy: 0.9729 - val_loss: 0.6649 - val_accuracy: 0.7193 - lr: 8.0000e-05
# Epoch 6/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9836
# Epoch 6: val_accuracy improved from 0.71931 to 0.77268, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 67s 337ms/step - loss: 0.0542 - accuracy: 0.9836 - val_loss: 0.5131 - val_accuracy: 0.7727 - lr: 8.0000e-05
# Epoch 7/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9798
# Epoch 7: val_accuracy did not improve from 0.77268
# 199/199 [==============================] - 62s 309ms/step - loss: 0.0547 - accuracy: 0.9798 - val_loss: 1.0611 - val_accuracy: 0.6477 - lr: 8.0000e-05
# Epoch 8/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9855
# Epoch 8: val_accuracy did not improve from 0.77268
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0369 - accuracy: 0.9855 - val_loss: 1.1537 - val_accuracy: 0.4317 - lr: 8.0000e-05
# Epoch 9/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9843
# Epoch 9: val_accuracy did not improve from 0.77268
# 199/199 [==============================] - 61s 309ms/step - loss: 0.0436 - accuracy: 0.9843 - val_loss: 0.9103 - val_accuracy: 0.6546 - lr: 8.0000e-05
# Epoch 10/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9918
# Epoch 10: val_accuracy did not improve from 0.77268
# 199/199 [==============================] - 61s 309ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.7710 - val_accuracy: 0.7237 - lr: 8.0000e-05
# Epoch 11/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9918
# Epoch 11: val_accuracy did not improve from 0.77268
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0209 - accuracy: 0.9918 - val_loss: 0.8012 - val_accuracy: 0.6980 - lr: 8.0000e-05
# Epoch 12/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9956
# Epoch 12: val_accuracy improved from 0.77268 to 0.86248, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 67s 336ms/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.3915 - val_accuracy: 0.8625 - lr: 8.0000e-05
# Epoch 13/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9962
# Epoch 13: val_accuracy did not improve from 0.86248
# 199/199 [==============================] - 62s 311ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 1.4699 - val_accuracy: 0.6838 - lr: 8.0000e-05
# Epoch 14/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9937
# Epoch 14: val_accuracy did not improve from 0.86248
# 199/199 [==============================] - 61s 307ms/step - loss: 0.0170 - accuracy: 0.9937 - val_loss: 1.0410 - val_accuracy: 0.7250 - lr: 8.0000e-05
# Epoch 15/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9937
# Epoch 15: val_accuracy improved from 0.86248 to 0.86719, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 67s 335ms/step - loss: 0.0158 - accuracy: 0.9937 - val_loss: 0.4406 - val_accuracy: 0.8672 - lr: 8.0000e-05
# Epoch 16/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9969
# Epoch 16: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 61s 308ms/step - loss: 0.0070 - accuracy: 0.9969 - val_loss: 1.3872 - val_accuracy: 0.5702 - lr: 8.0000e-05
# Epoch 17/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9943
# Epoch 17: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 0.6876 - val_accuracy: 0.7834 - lr: 8.0000e-05
# Epoch 18/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9981
# Epoch 18: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 61s 308ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 2.8433 - val_accuracy: 0.6628 - lr: 8.0000e-05
# Epoch 19/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9843
# Epoch 19: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 64s 324ms/step - loss: 0.0418 - accuracy: 0.9843 - val_loss: 2.2648 - val_accuracy: 0.3758 - lr: 8.0000e-05
# Epoch 20/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9899
# Epoch 20: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 62s 311ms/step - loss: 0.0259 - accuracy: 0.9899 - val_loss: 1.0719 - val_accuracy: 0.7055 - lr: 8.0000e-05
# Epoch 21/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9969
# Epoch 21: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 61s 307ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 1.0662 - val_accuracy: 0.6650 - lr: 8.0000e-05
# Epoch 22/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9962
# Epoch 22: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 1.4508 - val_accuracy: 0.5290 - lr: 8.0000e-05
# Epoch 23/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9918
# Epoch 23: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 61s 309ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 2.7725 - val_accuracy: 0.6634 - lr: 8.0000e-05
# Epoch 24/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9962
# Epoch 24: val_accuracy did not improve from 0.86719
# 199/199 [==============================] - 61s 309ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 1.9371 - val_accuracy: 0.4141 - lr: 8.0000e-05
# Epoch 25/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9981
# Epoch 25: val_accuracy improved from 0.86719 to 0.91743, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 66s 335ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.4015 - val_accuracy: 0.9174 - lr: 4.8000e-05
# Epoch 26/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9969
# Epoch 26: val_accuracy did not improve from 0.91743
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0064 - accuracy: 0.9969 - val_loss: 0.7112 - val_accuracy: 0.8738 - lr: 4.8000e-05
# Epoch 27/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9987
# Epoch 27: val_accuracy did not improve from 0.91743
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.3510 - val_accuracy: 0.9052 - lr: 4.8000e-05
# Epoch 28/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 28: val_accuracy improved from 0.91743 to 0.95196, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 66s 332ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9520 - lr: 4.8000e-05
# Epoch 29/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9975
# Epoch 29: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0062 - accuracy: 0.9975 - val_loss: 0.8856 - val_accuracy: 0.7246 - lr: 4.8000e-05
# Epoch 30/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9981
# Epoch 30: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0042 - accuracy: 0.9981 - val_loss: 0.8994 - val_accuracy: 0.7721 - lr: 4.8000e-05
# Epoch 31/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9975
# Epoch 31: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.3114 - val_accuracy: 0.9256 - lr: 4.8000e-05
# Epoch 32/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9975
# Epoch 32: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 61s 308ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 1.4571 - val_accuracy: 0.7068 - lr: 4.8000e-05
# Epoch 33/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 33: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 61s 309ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.9114 - val_accuracy: 0.8534 - lr: 4.8000e-05
# Epoch 34/50
# 199/199 [==============================] - ETA: 0s - loss: 7.7090e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 62s 310ms/step - loss: 7.7090e-04 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9495 - lr: 4.8000e-05
# Epoch 35/50
# 199/199 [==============================] - ETA: 0s - loss: 8.2915e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 61s 308ms/step - loss: 8.2915e-04 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9457 - lr: 4.8000e-05
# Epoch 36/50
# 199/199 [==============================] - ETA: 0s - loss: 4.0298e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.95196
# 199/199 [==============================] - 62s 310ms/step - loss: 4.0298e-04 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9513 - lr: 4.8000e-05
# Epoch 37/50
# 199/199 [==============================] - ETA: 0s - loss: 2.9082e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy improved from 0.95196 to 0.96044, saving model to /content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5
# 199/199 [==============================] - 67s 337ms/step - loss: 2.9082e-04 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9604 - lr: 4.8000e-05
# Epoch 38/50
# 199/199 [==============================] - ETA: 0s - loss: 8.2715e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 61s 308ms/step - loss: 8.2715e-04 - accuracy: 1.0000 - val_loss: 2.4212 - val_accuracy: 0.5893 - lr: 4.8000e-05
# Epoch 39/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 39: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.2197 - val_accuracy: 0.9538 - lr: 4.8000e-05
# Epoch 40/50
# 199/199 [==============================] - ETA: 0s - loss: 5.2669e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 61s 307ms/step - loss: 5.2669e-04 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9529 - lr: 4.8000e-05
# Epoch 41/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9994
# Epoch 41: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 61s 308ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.5328 - val_accuracy: 0.8653 - lr: 4.8000e-05
# Epoch 42/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9956
# Epoch 42: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 62s 311ms/step - loss: 0.0148 - accuracy: 0.9956 - val_loss: 1.3963 - val_accuracy: 0.6339 - lr: 4.8000e-05
# Epoch 43/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 62s 310ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8485 - val_accuracy: 0.7736 - lr: 4.8000e-05
# Epoch 44/50
# 199/199 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9981
# Epoch 44: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 61s 309ms/step - loss: 0.0041 - accuracy: 0.9981 - val_loss: 0.3281 - val_accuracy: 0.9203 - lr: 4.8000e-05
# Epoch 45/50
# 199/199 [==============================] - ETA: 0s - loss: 3.2183e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 61s 308ms/step - loss: 3.2183e-04 - accuracy: 1.0000 - val_loss: 0.1913 - val_accuracy: 0.9510 - lr: 4.8000e-05
# Epoch 46/50
# 199/199 [==============================] - ETA: 0s - loss: 3.8404e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 62s 310ms/step - loss: 3.8404e-04 - accuracy: 1.0000 - val_loss: 0.1801 - val_accuracy: 0.9526 - lr: 4.8000e-05
# Epoch 47/50
# 199/199 [==============================] - ETA: 0s - loss: 2.2492e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 61s 308ms/step - loss: 2.2492e-04 - accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9507 - lr: 4.8000e-05
# Epoch 48/50
# 199/199 [==============================] - ETA: 0s - loss: 1.0003e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 62s 311ms/step - loss: 1.0003e-04 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9542 - lr: 4.8000e-05
# Epoch 49/50
# 199/199 [==============================] - ETA: 0s - loss: 9.3939e-05 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 62s 310ms/step - loss: 9.3939e-05 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9576 - lr: 4.8000e-05
# Epoch 50/50
# 199/199 [==============================] - ETA: 0s - loss: 1.8623e-04 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.96044
# 199/199 [==============================] - 62s 311ms/step - loss: 1.8623e-04 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9542 - lr: 2.8800e-05

# %%
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])

plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
model=tf.keras.models.load_model('/content/drive/MyDrive/breast-cancer-classification/40X/40x_EfficientNetB4.h5')

# %%
data_test = data_test/255
model.evaluate(data_test, labels_test)
# Out:
# 13/13 [==============================] - 7s 216ms/step - loss: 0.1472 - accuracy: 0.9649
# [0.14719310402870178, 0.9649122953414917]

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(data_test, batch_size=1)
# Out:
# [INFO] evaluating network...
# 399/399 [==============================] - 10s 17ms/step

# %%
predIdxs = np.argmax(predIdxs, axis=1)
testY = np.argmax(labels_test, axis=1)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

print("precision_score : ",precision_score(testY, predIdxs  ,  average='weighted' ))
print("Recall Score : ",recall_score(testY, predIdxs ,average='weighted'))
print("f1_score : ",f1_score(testY, predIdxs ,average='weighted'))
# Out:
# precision_score :  0.9657541537240786
# Recall Score :  0.9649122807017544
# f1_score :  0.9650955689217471

# %%
target_names = ['Benign ', 'Malignant']
print(classification_report(testY, predIdxs, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Benign        0.93      0.97      0.95       134
#    Malignant       0.98      0.96      0.97       265
#
#     accuracy                           0.96       399
#    macro avg       0.96      0.97      0.96       399
# weighted avg       0.97      0.96      0.97       399

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(testY,predIdxs)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,  display_labels=target_names)
disp.plot(cmap=plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.title('Confusion matrix 40X_EfficientNetB4')
plt.ylabel("True labels")
plt.show()

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(testY , predIdxs)
false_positive_rate, true_positive_rate, threshold = roc_curve( testY , predIdxs)
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('40X_EfficientNetB4')
plt.legend(loc='best')
plt.show()
plt.close()
